# %% [markdown]
# <a href="https://colab.research.google.com/github/ekdls02/ekdls2025/blob/main/xai_%EA%B3%BC%EC%A0%9C_3_%EC%8A%A4%ED%8A%B8%EB%A0%88%EC%8A%A4_%EC%A7%80%EC%88%98_%EC%98%88%EC%B8%A1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 1. 라이브러리 임포트
import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.optimizers import Adam
from sklearn.metrics import accuracy_score


# 2. 데이터 불러오기
train = pd.read_csv("/content/train.csv")
test = pd.read_csv("/content/test.csv")


# 3. X, y 분리
X = train.drop("Stress Level", axis=1)
y = train["Stress Level"]


# 4. 문자열 feature -> 숫자 변환
str_cols = X.select_dtypes(include='object').columns
for col in str_cols:
    le_col = LabelEncoder()
    X[col] = le_col.fit_transform(X[col])

    # test 데이터에 unseen 값 처리
    test[col] = test[col].map(lambda s: s if s in le_col.classes_ else "Unknown")
    # "Unknown"도 encoder에 추가
    le_col.classes_ = np.append(le_col.classes_, "Unknown")
    test[col] = le_col.transform(test[col])


# 5. y(label) -> 숫자 -> 원-핫
le_y = LabelEncoder()
y_encoded = le_y.fit_transform(y)
y_categorical = to_categorical(y_encoded)


# 6. 결측치 처리
X = X.fillna(X.median())
test = test.fillna(test.median())


# 7. 스케일링
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)
test_scaled = scaler.transform(test)


# 8. 학습/검증 데이터 분리
X_train, X_valid, y_train, y_valid = train_test_split(
    X_scaled, y_categorical, test_size=0.2, random_state=42
)


# 9. ANN 모델 구성 (다중 클래스)
num_classes = y_categorical.shape[1]

model = Sequential([
    Dense(128, activation='relu', input_shape=(X_train.shape[1],)),
    Dropout(0.3),
    Dense(64, activation='relu'),
    Dropout(0.2),
    Dense(32, activation='relu'),
    Dense(num_classes, activation='softmax')  # 다중 클래스
])

optimizer = Adam(learning_rate=0.001)
model.compile(optimizer=optimizer,
              loss='categorical_crossentropy',
              metrics=['accuracy'])


# 10. 모델 학습
history = model.fit(X_train, y_train,
                    validation_data=(X_valid, y_valid),
                    epochs=50,
                    batch_size=16,
                    verbose=1)


# 11. 검증 정확도 확인
y_pred_valid = model.predict(X_valid)
y_pred_classes = np.argmax(y_pred_valid, axis=1)
y_valid_classes = np.argmax(y_valid, axis=1)
acc = accuracy_score(y_valid_classes, y_pred_classes)
print(f"Validation Accuracy: {acc:.5f}")


# 12. 테스트 데이터 예측
y_pred_test = model.predict(test_scaled)
y_pred_classes_test = np.argmax(y_pred_test, axis=1)
y_pred_labels_test = le_y.inverse_transform(y_pred_classes_test)


# 13. 제출 파일 생성
df = pd.read_csv("/content/submission.csv")
df.dropna(axis=1, inplace=True)
df["Stress Level"] = y_pred_labels_test
df.to_csv("new_submission.csv", index=False)

print("new_submission.csv 파일 생성 완료!")
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 6s 93ms/step - accuracy: 0.1710 - loss: 1.8047 - val_accuracy: 0.6833 - val_loss: 1.5344
# Epoch 2/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - accuracy: 0.5623 - loss: 1.5304 - val_accuracy: 0.8500 - val_loss: 1.2077
# Epoch 3/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7749 - loss: 1.2049 - val_accuracy: 0.8333 - val_loss: 0.8410
# Epoch 4/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8237 - loss: 0.9118 - val_accuracy: 0.9333 - val_loss: 0.5419
# Epoch 5/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8752 - loss: 0.6626 - val_accuracy: 0.9500 - val_loss: 0.3444
# Epoch 6/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8460 - loss: 0.5758 - val_accuracy: 0.9333 - val_loss: 0.2573
# Epoch 7/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8835 - loss: 0.4298 - val_accuracy: 0.9333 - val_loss: 0.2159
# Epoch 8/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9021 - loss: 0.3776 - val_accuracy: 0.9333 - val_loss: 0.1784
# Epoch 9/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9179 - loss: 0.3027 - val_accuracy: 0.9500 - val_loss: 0.1869
# Epoch 10/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9152 - loss: 0.2913 - val_accuracy: 0.9333 - val_loss: 0.1554
# Epoch 11/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9137 - loss: 0.3128 - val_accuracy: 0.9333 - val_loss: 0.1378
# Epoch 12/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8930 - loss: 0.3462 - val_accuracy: 0.9500 - val_loss: 0.1189
# Epoch 13/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9535 - loss: 0.1661 - val_accuracy: 0.9500 - val_loss: 0.1169
# Epoch 14/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9334 - loss: 0.2148 - val_accuracy: 0.9500 - val_loss: 0.1054
# Epoch 15/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9389 - loss: 0.1805 - val_accuracy: 0.9667 - val_loss: 0.0897
# Epoch 16/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9030 - loss: 0.2493 - val_accuracy: 0.9500 - val_loss: 0.0906
# Epoch 17/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.9094 - loss: 0.1942 - val_accuracy: 0.9667 - val_loss: 0.0834
# Epoch 18/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9467 - loss: 0.1485 - val_accuracy: 0.9833 - val_loss: 0.0809
# Epoch 19/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9440 - loss: 0.1739 - val_accuracy: 0.9833 - val_loss: 0.0735
# Epoch 20/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9716 - loss: 0.0974 - val_accuracy: 0.9667 - val_loss: 0.0730
# Epoch 21/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9773 - loss: 0.1154 - val_accuracy: 0.9500 - val_loss: 0.0727
# Epoch 22/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9578 - loss: 0.1488 - val_accuracy: 0.9667 - val_loss: 0.0610
# Epoch 23/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9395 - loss: 0.1504 - val_accuracy: 0.9833 - val_loss: 0.0872
# Epoch 24/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9754 - loss: 0.1089 - val_accuracy: 0.9833 - val_loss: 0.0730
# Epoch 25/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9784 - loss: 0.0904 - val_accuracy: 1.0000 - val_loss: 0.0582
# Epoch 26/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9720 - loss: 0.1116 - val_accuracy: 0.9667 - val_loss: 0.0526
# Epoch 27/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9562 - loss: 0.1045 - val_accuracy: 1.0000 - val_loss: 0.0476
# Epoch 28/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9591 - loss: 0.1029 - val_accuracy: 1.0000 - val_loss: 0.0520
# Epoch 29/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9894 - loss: 0.0658 - val_accuracy: 0.9833 - val_loss: 0.0543
# Epoch 30/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9646 - loss: 0.0961 - val_accuracy: 1.0000 - val_loss: 0.0450
# Epoch 31/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9715 - loss: 0.1131 - val_accuracy: 1.0000 - val_loss: 0.0397
# Epoch 32/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9785 - loss: 0.0708 - val_accuracy: 1.0000 - val_loss: 0.0360
# Epoch 33/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9530 - loss: 0.1298 - val_accuracy: 0.9833 - val_loss: 0.0515
# Epoch 34/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9642 - loss: 0.0998 - val_accuracy: 1.0000 - val_loss: 0.0375
# Epoch 35/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9776 - loss: 0.0704 - val_accuracy: 1.0000 - val_loss: 0.0319
# Epoch 36/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9753 - loss: 0.0983 - val_accuracy: 1.0000 - val_loss: 0.0333
# Epoch 37/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9892 - loss: 0.0704 - val_accuracy: 1.0000 - val_loss: 0.0276
# Epoch 38/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9717 - loss: 0.0865 - val_accuracy: 0.9833 - val_loss: 0.0420
# Epoch 39/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9820 - loss: 0.0941 - val_accuracy: 1.0000 - val_loss: 0.0288
# Epoch 40/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9827 - loss: 0.0665 - val_accuracy: 1.0000 - val_loss: 0.0235
# Epoch 41/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9975 - loss: 0.0497 - val_accuracy: 1.0000 - val_loss: 0.0225
# Epoch 42/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9715 - loss: 0.0905 - val_accuracy: 1.0000 - val_loss: 0.0181
# Epoch 43/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9786 - loss: 0.0792 - val_accuracy: 1.0000 - val_loss: 0.0184
# Epoch 44/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9976 - loss: 0.0453 - val_accuracy: 1.0000 - val_loss: 0.0177
# Epoch 45/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9732 - loss: 0.0751 - val_accuracy: 1.0000 - val_loss: 0.0194
# Epoch 46/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9850 - loss: 0.0517 - val_accuracy: 1.0000 - val_loss: 0.0216
# Epoch 47/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9868 - loss: 0.0481 - val_accuracy: 1.0000 - val_loss: 0.0189
# Epoch 48/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9681 - loss: 0.0793 - val_accuracy: 1.0000 - val_loss: 0.0155
# Epoch 49/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9630 - loss: 0.0745 - val_accuracy: 1.0000 - val_loss: 0.0193
# Epoch 50/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9829 - loss: 0.0487 - val_accuracy: 0.9833 - val_loss: 0.0292
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# Validation Accuracy: 0.98333
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# new_submission.csv 파일 생성 완료!
